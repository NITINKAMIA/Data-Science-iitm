# %%
import numpy as np
import matplotlib.pyplot as plt
arr=plt.imread(r"C:\Users\HP\Desktop\seven.jpg")
seven=arr.copy()
plt.imshow(seven)

# %%
seven.shape
# Out:
# (1080, 1920, 3)

# %%
a = np.random.randint(0,255,(50,50,3))
plt.imshow(a)

# %%
while True:
  import numpy as np
  import matplotlib.pyplot as plt
  import time
  a = np.random.randint(0,255,(5,5,3))
  plt.imshow(a)
  plt.show()
  time.sleep(0.3)
  display(clear = True)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       6 plt.imshow(a)
#       7 plt.show()
# ----> 8 time.sleep(0.3)
#       9 display(clear = True)
#
# KeyboardInterrupt:

# %%
a = np.random.randint(0,255,(4,4,3))
a
# Out:
# array([[[189,   5, 132],
#         [  9,  80,  95],
#         [181, 155,  99],
#         [170,  82,  39]],
#
#        [[  1, 243,  88],
#         [219,  46, 161],
#         [156, 224,  67],
#         [218, 146,  76]],
#
#        [[234, 128, 168],
#         [116, 226,  26],
#         [ 84,  18, 153],
#         [193, 111, 152]],
#
#        [[110, 166,  65],
#         [233, 231,  45],
#         [219, 199, 239],
#         [ 12, 172, 159]]], dtype=int32)

# %%
np.split(a,2)
# Out:
# [array([[[189,   5, 132],
#          [  9,  80,  95],
#          [181, 155,  99],
#          [170,  82,  39]],
#
#         [[  1, 243,  88],
#          [219,  46, 161],
#          [156, 224,  67],
#          [218, 146,  76]]], dtype=int32),
#  array([[[234, 128, 168],
#          [116, 226,  26],
#          [ 84,  18, 153],
#          [193, 111, 152]],
#
#         [[110, 166,  65],
#          [233, 231,  45],
#          [219, 199, 239],
#          [ 12, 172, 159]]], dtype=int32)]

# %%
final_arr=np.split(a,2)
len(final_arr)
# Out:
# 2

# %%
plt.imshow(a)

# %%
plt.imshow(final_arr[0])

# %%
plt.imshow(final_arr[1])

# %%
arr_1=np.split(a,2,axis=1)

# %%
len(arr_1)
# Out:
# 2

# %%
arr_3_part = np.split(a,3, axis = 2)

# %%
plt.imshow(a)

# %%
len(arr_3_part)
# Out:
# 3

# %%
plt.imshow(arr_3_part[0])

# %%
plt.imshow(arr_3_part[1])

# %%
plt.imshow(arr_3_part[2])

# %%
plt.imshow(np.split(seven,3,axis = 2)[2])

# %%
plt.imshow(np.split(seven,2,axis = 0)[1])

# %%
plt.imshow(np.split(seven,2,axis = 0)[0])

# %%
arr.shape
# Out:
# (1080, 1920, 3)

# %%
seven.shape
# Out:
# (1080, 1920, 3)

# %%
1000//3
# Out:
# 333

# %%
plt.imshow(seven[:,:333,:])

# %%
plt.imshow(seven[:,333:333*2,:])

# %%
plt.imshow(seven[:,333*2:,:])

# %%
a=np.random.randint(1,500,(4,4))
a
# Out:
# array([[292, 248,  44,  27],
#        [373,  22, 137,  19],
#        [ 80, 401, 311, 183],
#        [ 25, 133, 310, 396]], dtype=int32)

# %%
np.where(a>200,'High Sales','Low Sales')
# Out:
# array([['High Sales', 'High Sales', 'Low Sales', 'Low Sales'],
#        ['High Sales', 'Low Sales', 'Low Sales', 'Low Sales'],
#        ['Low Sales', 'High Sales', 'High Sales', 'Low Sales'],
#        ['Low Sales', 'Low Sales', 'High Sales', 'High Sales']],
#       dtype='<U10')

# %%
np.clip(a,100,200)
# Out:
# array([[200, 200, 100, 100],
#        [200, 100, 137, 100],
#        [100, 200, 200, 183],
#        [100, 133, 200, 200]], dtype=int32)

# %%
a = np.random.randint(1,10,7)
b = np.random.randint(1,10,(7,7))

print(a)
print('--------------------------------------------------------------------\n\n')
print(b)
# Out:
# [2 9 3 7 8 5 5]
# --------------------------------------------------------------------
#
#
# [[8 5 3 9 7 6 1]
#  [2 2 7 4 3 1 7]
#  [2 8 4 9 1 3 1]
#  [1 5 2 8 4 9 1]
#  [9 5 1 5 9 3 8]
#  [1 2 7 2 7 2 4]
#  [2 3 8 8 9 2 1]]

# %%
a * b
# Out:
# array([[16, 45,  9, 63, 56, 30,  5],
#        [ 4, 18, 21, 28, 24,  5, 35],
#        [ 4, 72, 12, 63,  8, 15,  5],
#        [ 2, 45,  6, 56, 32, 45,  5],
#        [18, 45,  3, 35, 72, 15, 40],
#        [ 2, 18, 21, 14, 56, 10, 20],
#        [ 4, 27, 24, 56, 72, 10,  5]], dtype=int32)

# %%
a+b
# Out:
# array([[10, 14,  6, 16, 15, 11,  6],
#        [ 4, 11, 10, 11, 11,  6, 12],
#        [ 4, 17,  7, 16,  9,  8,  6],
#        [ 3, 14,  5, 15, 12, 14,  6],
#        [11, 14,  4, 12, 17,  8, 13],
#        [ 3, 11, 10,  9, 15,  7,  9],
#        [ 4, 12, 11, 15, 17,  7,  6]], dtype=int32)

# %%
a1 = np.random.randint(1,10,(1,7))
b1 = np.random.randint(1,10,(7,1))

print(a1)
print('--------------------------------------------------------------------\n\n')
print(b1)
# Out:
# [[9 1 7 5 1 6 4]]
# --------------------------------------------------------------------
#
#
# [[8]
#  [1]
#  [5]
#  [7]
#  [9]
#  [9]
#  [2]]

# %%
a1+b1
# Out:
# array([[17,  9, 15, 13,  9, 14, 12],
#        [10,  2,  8,  6,  2,  7,  5],
#        [14,  6, 12, 10,  6, 11,  9],
#        [16,  8, 14, 12,  8, 13, 11],
#        [18, 10, 16, 14, 10, 15, 13],
#        [18, 10, 16, 14, 10, 15, 13],
#        [11,  3,  9,  7,  3,  8,  6]], dtype=int32)

# %%
a2 = np.random.randint(1,10,(1,1))
b2 = np.random.randint(1,10,(5,7))

print(a2)
print('--------------------------------------------------------------------\n\n')
print(b2)
# Out:
# [[1]]
# --------------------------------------------------------------------
#
#
# [[3 9 4 1 2 3 7]
#  [3 2 3 2 5 5 7]
#  [6 6 5 2 1 8 4]
#  [1 6 6 8 2 5 8]
#  [1 5 5 1 9 9 9]]

# %%
a2+b2
# Out:
# array([[ 4, 10,  5,  2,  3,  4,  8],
#        [ 4,  3,  4,  3,  6,  6,  8],
#        [ 7,  7,  6,  3,  2,  9,  5],
#        [ 2,  7,  7,  9,  3,  6,  9],
#        [ 2,  6,  6,  2, 10, 10, 10]], dtype=int32)

# %%
# introduction to pandas
# data: expolatory data analysis
import pandas as pd
pd.__version__
# Out:
# '2.2.3'

# %%
import numpy as np
import random

products = ['Chair','Tables','Laptop','Mobile Phones','Charger']
region = ['East','West','North','South']
all_date=pd.date_range('01-01-2025','23-07-2025')
data={'order_id':range(1,1001),
      'Data':random.choices(all_date,k=1000),
    'Region name':random.choices(region,k=1000),
     'Product name':random.choices(products,k=1000),
     'Sales':np.random.randint(100,10000,1000),
     'Qty':np.random.randint(1,10,1000),
     'Profit':np.random.randint(-10000,10000,1000)}
table=pd.DataFrame(data)
table
# Out:
#      order_id       Data Region name   Product name  Sales  Qty  Profit
# 0           1 2025-02-18        West  Mobile Phones   2229    4    1667
# 1           2 2025-05-06       North        Charger   3097    7    7257
# 2           3 2025-03-28        East  Mobile Phones   8076    3   -4500
# 3           4 2025-02-07        West  Mobile Phones    509    1    4379
# 4           5 2025-02-04       North         Tables   5204    3     789
# ..        ...        ...         ...            ...    ...  ...     ...
# 995       996 2025-03-26       South          Chair   3337    9    4323
# 996       997 2025-03-11       South         Laptop   6414    5   -8365
# 997       998 2025-03-05        West         Tables    911    6   -9093
# 998       999 2025-02-28       North        Charger   6123    7   -9370
# 999      1000 2025-05-20        East  Mobile Phones   4249    7   -4587
#
# [1000 rows x 7 columns]

# %%
pd.date_range('01-01-2025','23-07-2025')
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10',
#                ...
#                '2025-07-14', '2025-07-15', '2025-07-16', '2025-07-17',
#                '2025-07-18', '2025-07-19', '2025-07-20', '2025-07-21',
#                '2025-07-22', '2025-07-23'],
#               dtype='datetime64[ns]', length=204, freq='D')

# %%
table.head(10)
# Out:
#    order_id       Data Region name   Product name  Sales  Qty  Profit
# 0         1 2025-02-18        West  Mobile Phones   2229    4    1667
# 1         2 2025-05-06       North        Charger   3097    7    7257
# 2         3 2025-03-28        East  Mobile Phones   8076    3   -4500
# 3         4 2025-02-07        West  Mobile Phones    509    1    4379
# 4         5 2025-02-04       North         Tables   5204    3     789
# 5         6 2025-02-08       North  Mobile Phones   4252    1    4777
# 6         7 2025-04-20       North        Charger   8000    2    3858
# 7         8 2025-06-13       South         Laptop    895    5   -9931
# 8         9 2025-07-21       North         Laptop   9653    5   -2953
# 9        10 2025-03-11        West        Charger   5870    8    2205

# %%
table.sample(5)
# Out:
#      order_id       Data Region name   Product name  Sales  Qty  Profit
# 559       560 2025-01-04        West          Chair   4313    8   -6099
# 883       884 2025-07-05       South         Tables   5781    2   -3746
# 480       481 2025-01-18       North  Mobile Phones    489    4    7734
# 739       740 2025-06-06       South          Chair   7938    9   -7251
# 4           5 2025-02-04       North         Tables   5204    3     789

# %%
table.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   order_id      1000 non-null   int64
#  1   Data          1000 non-null   datetime64[ns]
#  2   Region name   1000 non-null   object
#  3   Product name  1000 non-null   object
#  4   Sales         1000 non-null   int32
#  5   Qty           1000 non-null   int32
#  6   Profit        1000 non-null   int32
# dtypes: datetime64[ns](1), int32(3), int64(1), object(2)
# memory usage: 43.1+ KB

# %%
table.columns
# Out:
# Index(['order_id', 'Data', 'Region name', 'Product name', 'Sales', 'Qty',
#        'Profit'],
#       dtype='object')

# %%
table.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
table.isna()
# Out:
#      order_id   Data  Region name  Product name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]

# %%
table.isna().value_counts()
# Out:
# order_id  Data   Region name  Product name  Sales  Qty    Profit
# False     False  False        False         False  False  False     1000
# Name: count, dtype: int64

# %%
table.isnull()
# Out:
#      order_id   Data  Region name  Product name  Sales    Qty  Profit
# 0       False  False        False         False  False  False   False
# 1       False  False        False         False  False  False   False
# 2       False  False        False         False  False  False   False
# 3       False  False        False         False  False  False   False
# 4       False  False        False         False  False  False   False
# ..        ...    ...          ...           ...    ...    ...     ...
# 995     False  False        False         False  False  False   False
# 996     False  False        False         False  False  False   False
# 997     False  False        False         False  False  False   False
# 998     False  False        False         False  False  False   False
# 999     False  False        False         False  False  False   False
#
# [1000 rows x 7 columns]
