# %%
f = open('day_4.txt',mode = 'w')
f.write('This is Day 4 of DS training!!')
f.close()
print('Done')
# Out:
# Done

# %%
#pip install googlesearch-python
# Out:
# Requirement already satisfied: googlesearch-python in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (1.3.0)
# Requirement already satisfied: beautifulsoup4>=4.9 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from googlesearch-python) (4.13.4)
# Requirement already satisfied: requests>=2.20 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from googlesearch-python) (2.32.4)
# Requirement already satisfied: soupsieve>1.2 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (2.7)
# Requirement already satisfied: typing-extensions>=4.0.0 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from beautifulsoup4>=4.9->googlesearch-python) (4.14.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->googlesearch-python) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->googlesearch-python) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->googlesearch-python) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\hp\appdata\local\programs\python\python313\lib\site-packages (from requests>=2.20->googlesearch-python) (2025.6.15)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from googlesearch import search
search("google",num_results=10)
# Out:
# <generator object search at 0x0000022265326BC0>

# %%
from googlesearch import search
list(search("Data Science",num_results=10))
# Out:
# ['https://www.ibm.com/think/topics/data-science',
#  'https://en.wikipedia.org/wiki/Data_science',
#  'https://www.coursera.org/browse/data-science',
#  'https://www.w3schools.com/datascience/',
#  'https://www.udemy.com/topic/data-science/?srsltid=AfmBOopgoiFqrQLzzn2djfRDHv1K4pF32j9m9D07pKPyXNInClCMEvpc',
#  'https://aws.amazon.com/what-is/data-science/',
#  'https://www.youtube.com/watch?v=OivTPt5LQh0',
#  'https://www.geeksforgeeks.org/data-science/data-science/',
#  'https://ischoolonline.berkeley.edu/data-science/what-is-data-science/',
#  'https://builtin.com/data-science']

# %%
from googlesearch import search
data = search('IITM',num_results=10)

all_data = []

for i in data:
  print(i)
# Out:
# /search?num=12
# https://www.iitm.ac.in/
# https://www.tropmet.res.in/
# https://www.iitmjanakpuri.com/
# https://en.wikipedia.org/wiki/IIT_Madras
# https://iitmpravartak.org.in/
# https://www.iitmz.ac.in/
# https://www.tropmet.res.in/Careers
# https://nptel.ac.in/
# https://iitm.irins.org/

# %%
from googlesearch import search
data = search('IITM',num_results=10)

all_data = []

for i in data:
   all_data.append(i+'\n')
    
file=open('Data Science.txt',mode='w')
file.writelines(all_data)
file.close()
print('done')
# Out:
# done

# %%
from googlesearch import search

title = 'Free Python Complete Tutorial PDF'

data = search(title,num_results=10)

all_data = []

for i in data:
  all_data.append(i+'\n')

file = open(f'{title}.txt',mode = 'w')
file.writelines(all_data)
file.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search

title = 'AI ML Complete Tutorial PDF'

data = search(title,num_results=15)

all_data = []

for i in data:
  all_data.append(i+'\n')

file = open(f'{title}.txt',mode = 'w')
file.writelines(all_data)
file.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search

title = 'Java Tutorial PDF'

data = search(title,num_results=50)

all_data = []

for i in data:
  all_data.append(i+'\n')

# Mode = x: it only create new file

file = open(f'{title}.txt',mode = 'x')
file.writelines(all_data)
file.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search

title = 'Chat Gpt Trending News'

data = search(title,num_results=5)

all_data = []

for i in data:
  all_data.append(i+'\n')

# Mode = a: It will append new line

file = open(f'{title}.txt',mode = 'a')
file.writelines(all_data)
file.close()
print('Done')
# Out:
# Done

# %%
from googlesearch import search

title = 'Chat Gpt Trending News'

data = search(title,num_results=5)

all_data = []

for i in data:
  all_data.append(i+'\n')

# Mode = a: It will append new line

file = open(f'{title}.txt',mode = 'a')
file.write("+++++++++++++++++++++++++++++++++++++++++++++++++++++++\n")
file.writelines(all_data)
file.close()
print('Done')
# Out:
# Done

# %%
# mode = +

# %%
f=open('day_4.txt','+r')
print(f.read())
f.write("\nwake up to reality nothing ever goes as planned in this acursed world the longer you live the more you realise that the only thing that exist is pain suffering and futality")
f.close()
# Out:
# This is Day 4 of DS training!!
# wake up to reality nothing ever goes as planned in this acursed world

# %%
f=open('day_4.txt','+w')
print(f.read())
f.write("\nwake up to reality nothing ever goes as planned in this acursed world the longer you live the more you realise that the only thing that exist is pain suffering and futality")
f.close()

# %%
f1=open('day_4.txt','r')
all_data=f1.read()
f2=open('Day_4copy.txt','w')
f2.write(all_data)
f1.close()
f2.close()

# %%
import qrcode
img = qrcode.make('https://github.com/NITINKAMIA/Data-Science-iitm.git')
img.save('mygithub.png')

# %% [markdown]
# Binary File Handling

# %%
path=r'''C:\Users\HP\Desktop\seven.jpg'''
file=open(path,mode='rb')
data=file.read()
print('done')
# Out:
# done

# %%
print(data[0:80])
# Out:
# b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x00\xff\xdb\x00C\x00\x08\x06\x06\x07\x06\x05\x08\x07\x07\x07\t\t\x08\n\x0c\x14\r\x0c\x0b\x0b\x0c\x19\x12\x13\x0f\x14\x1d\x1a\x1f\x1e\x1d\x1a\x1c\x1c $.\' ",#\x1c\x1c(7),01444\x1f\''

# %%
url='''https://images2.alphacoders.com/675/thumb-1920-675487.jpg'''
import requests as r
image_data=r.get(url).content

# %%
f = open('download_image.jpg','wb')
f.write(image_data)
f.close()

from IPython import display
display.Image('download_image.jpg')

# %%
url = '''https://picsum.photos/1500/1080'''
import requests as r
n = 10
for i in range(n):
  img_data = r.get(url).content
  f = open(f'image_{i}.jpg','wb')
  f.write(img_data)
  f.close()
  from IPython import display as d
  display(d.Image(f'image_{i}.jpg',width=200,height=200))

# %%
url_path = '''https://www.python.org/ftp/python/3.13.5/python-3.13.5-amd64.exe'''

import requests as r
with open(r'C:\Users\HP\Desktop\ds course\Nitin.exe','wb') as file:
    file.write(r.get(url_path).content)
    print("done")
# Out:
# done
